# %%
import pandas as pd
df = pd.read_csv('uncleaned_data.csv')

# %%
df.head()
# Out:
#    Not at all  1-2 hours  3-4 hours  5-6 hours  More than 6 hours  \
# 0         NaN        NaN        3.0        NaN                NaN
# 1         NaN        NaN        3.0        NaN                NaN
# 2         NaN        NaN        3.0        NaN                NaN
# 3         NaN        2.0        NaN        NaN                NaN
# 4         NaN        NaN        NaN        NaN                5.0
#
#    Strongly agree  Agree  Neither agree or disagree  Disagree  \
# 0             1.0    NaN                        NaN       NaN
# 1             1.0    NaN                        NaN       NaN
# 2             NaN    NaN                        3.0       NaN
# 3             1.0    NaN                        NaN       NaN
# 4             NaN    2.0                        NaN       NaN
#
#    Strongly disagree  ...  Always.4  Usually.4  Sometimes.4  Rarely.4  \
# 0                NaN  ...       NaN        NaN          3.0       NaN
# ...

# %%
df.shape
# Out:
# (665, 70)

# %%
df.isna().sum()
# Out:
# Not at all           651
# 1-2 hours            382
# 3-4 hours            372
# 5-6 hours            613
# More than 6 hours    643
#                     ...
# Not at all.1         133
# 1-2 times            553
# 3-4 times            652
# 4-5 times            664
# More than 5 times    659
# Length: 70, dtype: int64
